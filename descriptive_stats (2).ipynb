# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Universities.csv")
print(df)
plt.boxplot(df["SAT"])
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# 13     PennState  1081     38      54       18     10185        80
# 14     Princeton  1375     91      14        8     30220        95
# 15        Purdue  1005     28      90       19      9066        69
# 16      Stanford  1360     90      20       12     36450        93
# 17      TexasA&M  1075     49      67       25      8704        67
# 18    UCBerkeley  1240     95      40       17     15140        78
# 19      UChicago  1290     75      50       13     38380        87
# 20     UMichigan  1180     65      68       16     15470        85
# 21         UPenn  1285     80      36       11     27553        90
# 22           UVA  1225     77      44       14     13349        92
# 23    UWisconsin  1085     40      69       15     11857        71
# 24          Yale  1375     95      19       11     43514        96
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7aa23620>,
#   <matplotlib.lines.Line2D at 0x1df7aa238f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7aa23b60>,
#   <matplotlib.lines.Line2D at 0x1df7aa23e30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7aa233b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7aa4c0e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7aa4c3e0>],
#  'means': []}

# %%
plt.boxplot(df["Accept"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7aa4f1d0>,
#   <matplotlib.lines.Line2D at 0x1df7a8b18e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7a8b2450>,
#   <matplotlib.lines.Line2D at 0x1df7a954dd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7aa4ecf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7aa67350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7aa66e70>],
#  'means': []}

# %%
plt.boxplot(df["Top10"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7aa83b60>,
#   <matplotlib.lines.Line2D at 0x1df7aa83e30>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7aab8170>,
#   <matplotlib.lines.Line2D at 0x1df7aa82660>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7aa83950>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7aab85f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7aab8890>],
#  'means': []}

# %%
plt.boxplot(df["SFRatio"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7aae30b0>,
#   <matplotlib.lines.Line2D at 0x1df7ab440b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7ab44350>,
#   <matplotlib.lines.Line2D at 0x1df7aae1c70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7aae13a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7ab44740>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7ab44a10>],
#  'means': []}

# %%
plt.boxplot(df["Expenses"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7ab92930>,
#   <matplotlib.lines.Line2D at 0x1df7ab92c00>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7ab92ed0>,
#   <matplotlib.lines.Line2D at 0x1df7ab914c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7aa66e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7ab931d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7ab934d0>],
#  'means': []}

# %%
plt.boxplot(df["GradRate"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7ac0c5c0>,
#   <matplotlib.lines.Line2D at 0x1df7ac0c890>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7ac0cb60>,
#   <matplotlib.lines.Line2D at 0x1df7abd6ff0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7ac0c380>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7ac0cd10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7ac0d0a0>],
#  'means': []}

# %%
np.mean(df["SAT"])
# Out:
# 1266.44

# %%
np.median(df["SAT"])
# Out:
# 1285.0

# %%
np.std(df["GradRate"])
# Out:
# 8.874773236539623

# %%
np.var(df["SFRatio"])
# Out:
# 15.881599999999999

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
plt.title("Acceptance Ratio")
plt.hist(df["Accept"])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df["Top10"], kde =True)
# Out:
# <Axes: xlabel='Top10', ylabel='Count'>

# %%
sns.histplot(df["Accept"], kde =True)
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df["Expenses"], kde =True)
# Out:
# <Axes: xlabel='Expenses', ylabel='Count'>

# %%
sns.histplot(df["SAT"], kde =True)
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
s1 = [15,50,60,70,45,65]
scores1 = pd.Series(s1)
scores1
# Out:
# 0    15
# 1    50
# 2    60
# 3    70
# 4    45
# 5    65
# dtype: int64

# %%
plt.boxplot(scores1, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7a63df40>,
#   <matplotlib.lines.Line2D at 0x1df7a63e1b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7a63e480>,
#   <matplotlib.lines.Line2D at 0x1df7a63e720>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7a5f74a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7a63e900>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7a63eba0>],
#  'means': []}

# %%
s2=[0,10,15,40,60,530,140]
scores2 = pd.Series(s2)
scores2
# Out:
# 0      0
# 1     10
# 2     15
# 3     40
# 4     60
# 5    530
# 6    140
# dtype: int64

# %%
plt.boxplot(scores2, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df7a8230b0>,
#   <matplotlib.lines.Line2D at 0x1df7a8233b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df7a823620>,
#   <matplotlib.lines.Line2D at 0x1df7a823920>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df7a822de0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df7a823ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df7a823d10>],
#  'means': []}
